# %% [markdown]
# # SQL to identify events from the WCA database:
#
# <code>SELECT id
# FROM WCA.events
# WHERE rank < 997
# ORDER BY rank</code>
#
# <code>333
# 444
# 555
# 222
# 333bf
# 333oh
# 333fm
# 333ft
# minx
# pyram
# sq1
# clock
# skewb
# 666
# 777
# 444bf
# 555bf
# 333mbf</code>

# %%
events = ['333', '444', '555', '222', '333bf', '333oh', '333fm', '333ft', 'minx',
              'pyram', 'sq1', 'clock', 'skewb', '666', '777', '444bf', '555bf', '333mbf']

# %%
for eventId in events:
    print "-- %s" % eventId
    print "numComp%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numFinal%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numPodium%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numRound%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numAttempt%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numSuccess%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numDns%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numDnf%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numSingleWr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numAverageWr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numSingleCr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numAverageCr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numSingleNr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "numAverageNr%s SMALLINT DEFAULT 0 NOT NULL," % (eventId)
    print "totTime%s BIGINT DEFAULT 0 NOT NULL," % (eventId)
        
    print "bestSingle%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "worldRankSingle%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "continentRankSingle%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "countryRankSingle%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "worldCentileSingle%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
    print "continentCentileSingle%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
    print "countryCentileSingle%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
    
    print "bestAverage%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "worldRankAverage%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "continentRankAverage%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "countryRankAverage%s INT DEFAULT 0 NOT NULL," % (eventId)
    print "worldCentileAverage%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
    print "continentCentileAverage%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
    print "countryCentileAverage%s TINYINT DEFAULT 0 NOT NULL," % (eventId)
# Out:
# -- 333
# numComp333 SMALLINT DEFAULT 0 NOT NULL,
# numFinal333 SMALLINT DEFAULT 0 NOT NULL,
# numPodium333 SMALLINT DEFAULT 0 NOT NULL,
# numRound333 SMALLINT DEFAULT 0 NOT NULL,
# numAttempt333 SMALLINT DEFAULT 0 NOT NULL,
# numSuccess333 SMALLINT DEFAULT 0 NOT NULL,
# numDns333 SMALLINT DEFAULT 0 NOT NULL,
# numDnf333 SMALLINT DEFAULT 0 NOT NULL,
# numSingleWr333 SMALLINT DEFAULT 0 NOT NULL,
# numAverageWr333 SMALLINT DEFAULT 0 NOT NULL,
# numSingleCr333 SMALLINT DEFAULT 0 NOT NULL,
# numAverageCr333 SMALLINT DEFAULT 0 NOT NULL,
# numSingleNr333 SMALLINT DEFAULT 0 NOT NULL,
# numAverageNr333 SMALLINT DEFAULT 0 NOT NULL,
# totTime333 BIGINT DEFAULT 0 NOT NULL,
# bestSingle333 INT DEFAULT 0 NOT NULL,
# worldRankSingle333 INT DEFAULT 0 NOT NULL,
# continentRankSingle333 INT DEFAULT 0 NOT NULL,
# countryRankSingle333 INT DEFAULT 0 NOT NULL,
# worldCentileSingle333 TINYINT DEFAULT 0 NOT NULL,
# continentCentileSingle333 TINYINT DEFAULT 0 NOT NULL,
# ...

# %%
for eventId in events:
    print "-- %s" % eventId
    print "IFNULL(r.numComp%s, 0)," % (eventId)
    print "IFNULL(r.numFinal%s, 0)," % (eventId)
    print "IFNULL(r.numPodium%s, 0)," % (eventId)
    print "IFNULL(r.numRound%s, 0)," % (eventId)
    print "IFNULL(r.numAttempt%s, 0)," % (eventId)
    print "IFNULL(r.numSuccess%s, 0)," % (eventId)
    print "IFNULL(r.numDns%s, 0)," % (eventId)
    print "IFNULL(r.numDnf%s, 0)," % (eventId)
    print "IFNULL(r.numSingleWr%s, 0)," % (eventId)
    print "IFNULL(r.numAverageWr%s, 0)," % (eventId)
    print "IFNULL(r.numSingleCr%s, 0)," % (eventId)
    print "IFNULL(r.numAverageCr%s, 0)," % (eventId)
    print "IFNULL(r.numSingleNr%s, 0)," % (eventId)
    print "IFNULL(r.numAverageNr%s, 0)," % (eventId)
    print "IFNULL(r.totTime%s, 0)," % (eventId)
    
    print "IFNULL(rs.best%s, 0)," % (eventId)
    print "IFNULL(rs.worldRank%s, 0)," % (eventId)
    print "IFNULL(rs.continentRank%s, 0)," % (eventId)
    print "IFNULL(rs.countryRank%s, 0)," % (eventId)
    print "IFNULL(rs.worldCentile%s, 0)," % (eventId)
    print "IFNULL(rs.continentCentile%s, 0)," % (eventId)
    print "IFNULL(rs.countryCentile%s, 0)," % (eventId)
    
    print "IFNULL(ra.best%s, 0)," % (eventId)
    print "IFNULL(ra.worldRank%s, 0)," % (eventId)
    print "IFNULL(ra.continentRank%s, 0)," % (eventId)
    print "IFNULL(ra.countryRank%s, 0)," % (eventId)
    print "IFNULL(ra.worldCentile%s, 0)," % (eventId)
    print "IFNULL(ra.continentCentile%s, 0)," % (eventId)
    print "IFNULL(ra.countryCentile%s, 0)," % (eventId)
# Out:
# -- 333
# IFNULL(r.numComp333, 0),
# IFNULL(r.numFinal333, 0),
# IFNULL(r.numPodium333, 0),
# IFNULL(r.numRound333, 0),
# IFNULL(r.numAttempt333, 0),
# IFNULL(r.numSuccess333, 0),
# IFNULL(r.numDns333, 0),
# IFNULL(r.numDnf333, 0),
# IFNULL(r.numSingleWr333, 0),
# IFNULL(r.numAverageWr333, 0),
# IFNULL(r.numSingleCr333, 0),
# IFNULL(r.numAverageCr333, 0),
# IFNULL(r.numSingleNr333, 0),
# IFNULL(r.numAverageNr333, 0),
# IFNULL(r.totTime333, 0),
# IFNULL(rs.best333, 0),
# IFNULL(rs.worldRank333, 0),
# IFNULL(rs.continentRank333, 0),
# IFNULL(rs.countryRank333, 0),
# IFNULL(rs.worldCentile333, 0),
# IFNULL(rs.continentCentile333, 0),
# IFNULL(rs.countryCentile333, 0),
# IFNULL(ra.best333, 0),
# IFNULL(ra.worldRank333, 0),
# IFNULL(ra.continentRank333, 0),
# IFNULL(ra.countryRank333, 0),
# IFNULL(ra.worldCentile333, 0),
# IFNULL(ra.continentCentile333, 0),
# IFNULL(ra.countryCentile333, 0),
# -- 444
# IFNULL(r.numComp444, 0),
# IFNULL(r.numFinal444, 0),
# IFNULL(r.numPodium444, 0),
# ...
